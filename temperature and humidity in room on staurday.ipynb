# %%
import matplotlib.pyplot as pt
import pandas as pd


data = pd.read_csv('energydata_trainning.csv')
temp_humidity = data[['T1','RH_1','Day_of_week']]
temp_humidity
# Out:
#               T1       RH_1 Day_of_week
# 0      19.890000  47.596667      Monday
# 1      19.890000  46.693333      Monday
# 2      19.890000  46.300000      Monday
# 3      19.890000  46.333333      Monday
# 4      19.890000  46.026667      Monday
# 5      19.856667  45.560000      Monday
# 6      19.790000  45.597500      Monday
# 7      19.856667  46.090000      Monday
# 8      20.133333  48.000000      Monday
# 9      20.260000  52.726667      Monday
# 10     20.426667  55.893333      Monday
# 11     20.730000  52.660000      Monday
# 12     20.890000  51.193333      Monday
# 13     20.890000  49.800000      Monday
# 14     20.890000  48.433333      Monday
# 15     21.100000  46.596667      Monday
# 16     21.133333  46.060000      Monday
# 17     21.200000  45.800000      Monday
# 18     21.290000  45.900000      Monday
# 19     21.390000  45.690000      Monday
# 20     21.500000  45.333333      Monday
# 21     21.500000  45.126667      Monday
# ...

# %%
temp_humidity_saturday = temp_humidity[data.Day_of_week == 'Saturday']
temp_humidity_saturday
# Out:
#               T1       RH_1 Day_of_week
# 471    23.000000  40.000000    Saturday
# 472    22.890000  40.126667    Saturday
# 473    22.890000  40.200000    Saturday
# 474    22.790000  40.090000    Saturday
# 475    22.790000  40.163333    Saturday
# 476    22.760000  40.230000    Saturday
# 477    22.700000  40.290000    Saturday
# 478    22.666667  40.290000    Saturday
# 479    22.600000  40.290000    Saturday
# 480    22.500000  40.290000    Saturday
# 481    22.390000  40.200000    Saturday
# 482    22.356667  40.200000    Saturday
# 483    22.290000  40.200000    Saturday
# 484    22.200000  40.090000    Saturday
# 485    22.200000  40.090000    Saturday
# 486    22.166667  40.090000    Saturday
# 487    22.100000  40.090000    Saturday
# 488    22.066667  40.060000    Saturday
# 489    21.963333  40.000000    Saturday
# 490    21.890000  40.000000    Saturday
# 491    21.890000  40.000000    Saturday
# 492    21.890000  40.000000    Saturday
# ...

# %%
avg_temp_saturday = temp_humidity_saturday['T1'].mean()
avg_temp_saturday
# Out:
# 21.59019933758942

# %%
temp_humidity_sunday = temp_humidity[data.Day_of_week == 'Sunday']
temp_humidity_sunday
# Out:
#               T1       RH_1 Day_of_week
# 571    22.500000  39.363333      Sunday
# 572    22.426667  39.290000      Sunday
# 573    22.323333  39.363333      Sunday
# 574    22.230000  39.500000      Sunday
# 575    22.200000  39.500000      Sunday
# 576    22.133333  39.560000      Sunday
# 577    22.066667  39.663333      Sunday
# 578    22.000000  39.663333      Sunday
# 579    22.000000  39.700000      Sunday
# 580    21.790000  39.700000      Sunday
# 581    21.760000  39.790000      Sunday
# 582    21.700000  39.790000      Sunday
# 583    21.500000  40.000000      Sunday
# 584    21.426667  40.030000      Sunday
# 585    21.390000  40.000000      Sunday
# 586    21.390000  40.060000      Sunday
# 587    21.290000  40.090000      Sunday
# 588    21.290000  40.090000      Sunday
# 589    21.290000  40.200000      Sunday
# 590    21.230000  40.200000      Sunday
# 591    21.200000  40.200000      Sunday
# 592    21.100000  40.290000      Sunday
# ...

# %%
avg_temp_sunday = temp_humidity_sunday['T1'].mean()
avg_temp_sunday
# Out:
# 21.811175584079333

# %%
avg_humidity_saturday = temp_humidity_saturday['RH_1'].mean()
avg_humidity_saturday
# Out:
# 40.027873782333224
