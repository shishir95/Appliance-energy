# %%
import matplotlib.pyplot as pt
import pandas as pd

fig = pt.figure()
ax = pt.axes(projection="3d")


data = pd.read_csv('energydata_trainning.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-f99e337ee361> in <module>
#       2 import pandas as pd
#       3
# ----> 4 fig = plt.figure()
#       5 ax = pt.axes(projection="3d")
#       6
#
# NameError: name 'plt' is not defined

# %%
energy_data = data[['','T1','RH_1','T2','RH_2','T3','RH_3','T4','RH_4','T5','RH_5','T6','RH_6','T7','RH_7','T8','RH_8','T9','RH_9']]
energy_data
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              60  19.890000  46.333333  19.200000  44.530000  19.790000
# 4              50  19.890000  46.026667  19.200000  44.500000  19.790000
# 5              60  19.856667  45.560000  19.200000  44.500000  19.730000
# 6              60  19.790000  45.597500  19.200000  44.433333  19.730000
# 7              70  19.856667  46.090000  19.230000  44.400000  19.790000
# 8             430  20.133333  48.000000  19.566667  44.400000  19.890000
# 9             250  20.260000  52.726667  19.730000  45.100000  19.890000
# 10            100  20.426667  55.893333  19.856667  45.833333  20.033333
# 11             90  20.730000  52.660000  20.166667  47.223333  20.200000
# ...

# %%
tmp=data.loc[:, ['T1', 'T2','T3','T4','T5','T6','T7','T8','T9']]
tmp
# Out:
#               T1         T2         T3         T4         T5         T6  \
# 0      19.890000  19.200000  19.790000  19.000000  17.166667   7.026667
# 1      19.890000  19.200000  19.790000  19.000000  17.166667   6.833333
# 2      19.890000  19.200000  19.790000  18.926667  17.166667   6.560000
# 3      19.890000  19.200000  19.790000  18.890000  17.200000   6.366667
# 4      19.890000  19.200000  19.790000  18.890000  17.133333   6.300000
# 5      19.856667  19.200000  19.730000  18.890000  17.100000   6.190000
# 6      19.790000  19.200000  19.730000  18.890000  17.166667   6.123333
# 7      19.856667  19.230000  19.790000  18.890000  17.100000   6.190000
# 8      20.133333  19.566667  19.890000  19.000000  17.100000   6.123333
# 9      20.260000  19.730000  19.890000  19.000000  17.100000   6.067500
# 10     20.426667  19.856667  20.033333  19.000000  17.100000   5.900000
# 11     20.730000  20.166667  20.200000  18.926667  17.166667   5.726667
# ...

# %% [markdown]
# x1=tmp.mean(axis=1)
# x1

# %%
x1=tmp.mean(axis=1)

# %%
x1
# Out:
# 0        17.167407
# 1        17.149630
# 2        17.103704
# 3        17.070741
# 4        17.048519
# 5        17.018519
# 6        17.018519
# 7        17.039630
# 8        17.185185
# 9        17.214907
# 10       17.252222
# 11       17.310741
# 12       17.319630
# 13       17.374815
# 14       17.465000
# 15       17.548889
# 16       17.612222
# 17       17.693333
# 18       17.711481
# 19       17.787037
# 20       17.846111
# 21       17.867037
# 22       17.890000
# 23       17.965556
# 24       18.032037
# 25       18.094444
# 26       18.154167
# 27       18.132593
# 28       18.098519
# 29       18.052778
#            ...
# 14773    24.718148
# 14774    24.681323
# 14775    24.709259
# 14776    24.758307
# 14777    24.788889
# 14778    24.817989
# 14779    24.836931
# 14780    24.914519
# 14781    24.940000
# 14782    24.921005
# 14783    24.893685
# 14784    24.874709
# 14785    24.961693
# 14786    25.058148
# 14787    25.033571
# 14788    25.023704
# ...

# %%
h=data.loc[:, ['RH_1', 'RH_2','RH_3','RH_4','RH_5','RH_6','RH_7','RH_8','RH_9']]
x2=h.mean(axis=1)

# %%
x2
# Out:
# 0        50.910741
# 1        50.827222
# 2        50.628889
# 3        50.732963
# 4        50.791852
# 5        50.802963
# 6        50.901944
# 7        51.050741
# 8        51.854074
# 9        52.675000
# 10       53.519815
# 11       53.378889
# 12       52.969630
# 13       54.367037
# 14       55.069259
# 15       54.445185
# 16       54.684074
# 17       54.529259
# 18       53.285926
# 19       52.029259
# 20       51.731481
# 21       51.407222
# 22       51.095926
# 23       50.907407
# 24       50.614630
# 25       50.363704
# 26       50.285741
# 27       50.499630
# 28       50.649259
# 29       50.788981
#            ...
# 14773    40.881259
# 14774    40.861389
# 14775    40.880085
# 14776    40.885884
# 14777    40.886138
# 14778    40.990635
# 14779    41.062222
# 14780    41.108003
# 14781    41.111407
# 14782    40.996349
# 14783    41.043194
# 14784    41.010899
# 14785    40.793492
# 14786    40.642148
# 14787    40.588545
# 14788    40.532963
# ...

# %%
table = {'Appliances':[data.Appliances], 'X1': x1[:1]}
pd.DataFrame(table)
# Out:
#                                           Appliances         X1
# 0  0         60
# 1         60
# 2         50
# 3      ...  17.167407

# %%
pt.scatter(x1,data.Appliances)

# %%
table =data.loc[:, ['Appliances','x1.loci[:,1]']]
# Out:
#   File "<ipython-input-56-c1c47dee20b9>", line 1
#     table =data.loc[:, ['Appliances','x1.loci[:,1]]]
#                                                     ^
# SyntaxError: EOL while scanning string literal
