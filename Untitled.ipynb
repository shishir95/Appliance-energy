# %%
import matplotlib.pyplot as pt
import pandas as pd
data = pd.read_csv('energydata_trainning.csv')
appliences_energy = data[['Appliances','WeekStatus']]
appliences_energy
# Out:
#        Appliances WeekStatus
# 0              60    Weekday
# 1              60    Weekday
# 2              50    Weekday
# 3              60    Weekday
# 4              50    Weekday
# 5              60    Weekday
# 6              60    Weekday
# 7              70    Weekday
# 8             430    Weekday
# 9             250    Weekday
# 10            100    Weekday
# 11             90    Weekday
# 12             80    Weekday
# 13            140    Weekday
# 14            120    Weekday
# 15            110    Weekday
# 16            110    Weekday
# 17            110    Weekday
# 18            100    Weekday
# 19            100    Weekday
# 20            100    Weekday
# 21            110    Weekday
# 22            400    Weekday
# 23            400    Weekday
# 24            390    Weekday
# 25            240    Weekday
# 26             60    Weekday
# 27             60    Weekday
# 28             50    Weekday
# 29             70    Weekday
# ...           ...        ...
# ...

# %%
appliences_energy_weekday = appliences_energy[data.WeekStatus == 'Weekday']
appliences_energy_weekday
# Out:
#        Appliances WeekStatus
# 0              60    Weekday
# 1              60    Weekday
# 2              50    Weekday
# 3              60    Weekday
# 4              50    Weekday
# 5              60    Weekday
# 6              60    Weekday
# 7              70    Weekday
# 8             430    Weekday
# 9             250    Weekday
# 10            100    Weekday
# 11             90    Weekday
# 12             80    Weekday
# 13            140    Weekday
# 14            120    Weekday
# 15            110    Weekday
# 16            110    Weekday
# 17            110    Weekday
# 18            100    Weekday
# 19            100    Weekday
# 20            100    Weekday
# 21            110    Weekday
# 22            400    Weekday
# 23            400    Weekday
# 24            390    Weekday
# 25            240    Weekday
# 26             60    Weekday
# 27             60    Weekday
# 28             50    Weekday
# 29             70    Weekday
# ...           ...        ...
# ...

# %%
avg_energy_weekday = appliences_energy_weekday['Appliances'].mean()
avg_energy_weekday
# Out:
# 96.6035447761194

# %%
appliences_energy_weekend = appliences_energy[data.WeekStatus == 'Weekend']
appliences_energy_weekend
# Out:
#        Appliances WeekStatus
# 471            50    Weekend
# 472            50    Weekend
# 473            30    Weekend
# 474            20    Weekend
# 475            40    Weekend
# 476            50    Weekend
# 477            50    Weekend
# 478            50    Weekend
# 479            60    Weekend
# 480            50    Weekend
# 481            50    Weekend
# 482            50    Weekend
# 483            50    Weekend
# 484            30    Weekend
# 485            30    Weekend
# 486            40    Weekend
# 487            50    Weekend
# 488            50    Weekend
# 489            50    Weekend
# 490            60    Weekend
# 491            50    Weekend
# 492            50    Weekend
# 493            50    Weekend
# 494            50    Weekend
# 495            40    Weekend
# 496            60    Weekend
# 497            60    Weekend
# 498            50    Weekend
# 499           220    Weekend
# 500           390    Weekend
# ...           ...        ...
# ...

# %%
avg_energy_weekend = appliences_energy_weekend['Appliances'].mean()
avg_energy_weekend
# Out:
# 101.70707812882684

# %%
appliance_energy = [avg_energy_weekday,avg_energy_weekend]
week_days = ['weekday','weekend']
pt.bar(week_days,appliance_energy,color='g',width=0.30,label='Appliences')
pt.xlabel('Weekdays')
pt.ylabel('Appliences energy in weekday')
pt.title('Average applienes energy in weekday')
pt.legend(loc=(1.1,0.4))
