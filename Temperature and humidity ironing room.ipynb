# %%
import matplotlib.pyplot as pt
import pandas as pd


data = pd.read_csv('energydata_trainning.csv')
temp_humidity = data[['T7','RH_7','Day_of_week']]
temp_humidity
# Out:
#               T7       RH_7 Day_of_week
# 0      17.200000  41.626667      Monday
# 1      17.200000  41.560000      Monday
# 2      17.200000  41.433333      Monday
# 3      17.200000  41.230000      Monday
# 4      17.133333  41.260000      Monday
# 5      17.100000  41.200000      Monday
# 6      17.166667  41.400000      Monday
# 7      17.200000  41.500000      Monday
# 8      17.823333  45.493333      Monday
# 9      17.963333  46.160000      Monday
# 10     17.963333  45.533333      Monday
# 11     17.760000  44.266667      Monday
# 12     17.666667  43.160000      Monday
# 13     17.600000  42.693333      Monday
# 14     17.600000  42.333333      Monday
# 15     17.760000  43.633333      Monday
# 16     17.856667  43.460000      Monday
# 17     17.790000  43.400000      Monday
# 18     17.890000  43.790000      Monday
# 19     17.890000  43.700000      Monday
# 20     17.865000  43.570000      Monday
# 21     17.790000  43.400000      Monday
# ...

# %%
temp_humidity_monday = temp_humidity[data.Day_of_week == 'Monday']
temp_humidity_monday
# Out:
#               T7       RH_7 Day_of_week
# 0      17.200000  41.626667      Monday
# 1      17.200000  41.560000      Monday
# 2      17.200000  41.433333      Monday
# 3      17.200000  41.230000      Monday
# 4      17.133333  41.260000      Monday
# 5      17.100000  41.200000      Monday
# 6      17.166667  41.400000      Monday
# 7      17.200000  41.500000      Monday
# 8      17.823333  45.493333      Monday
# 9      17.963333  46.160000      Monday
# 10     17.963333  45.533333      Monday
# 11     17.760000  44.266667      Monday
# 12     17.666667  43.160000      Monday
# 13     17.600000  42.693333      Monday
# 14     17.600000  42.333333      Monday
# 15     17.760000  43.633333      Monday
# 16     17.856667  43.460000      Monday
# 17     17.790000  43.400000      Monday
# 18     17.890000  43.790000      Monday
# 19     17.890000  43.700000      Monday
# 20     17.865000  43.570000      Monday
# 21     17.790000  43.400000      Monday
# ...

# %%
avg_temp_monday = temp_humidity_monday['T7'].mean()
avg_temp_monday
# Out:
# 20.512940308091974

# %%
temp_humidity_tuesday = temp_humidity[data.Day_of_week == 'Tuesday']
temp_humidity_tuesday
# Out:
#               T7       RH_7 Day_of_week
# 32     17.700000  43.760000     Tuesday
# 33     17.700000  43.933333     Tuesday
# 34     17.760000  44.333333     Tuesday
# 35     17.790000  44.963333     Tuesday
# 36     17.790000  45.223333     Tuesday
# 37     17.790000  45.425000     Tuesday
# 38     17.790000  45.730000     Tuesday
# 39     17.790000  45.826667     Tuesday
# 40     17.790000  45.966667     Tuesday
# 41     17.790000  46.000000     Tuesday
# 42     17.790000  46.000000     Tuesday
# 43     17.890000  46.060000     Tuesday
# 44     17.890000  46.090000     Tuesday
# 45     17.856667  45.966667     Tuesday
# 46     17.856667  45.966667     Tuesday
# 47     17.890000  46.200000     Tuesday
# 48     17.890000  46.200000     Tuesday
# 49     17.890000  45.920000     Tuesday
# 50     17.890000  45.730000     Tuesday
# 51     17.890000  45.700000     Tuesday
# 52     17.890000  45.700000     Tuesday
# 53     17.890000  45.590000     Tuesday
# ...

# %%
avg_temp_tuesday = temp_humidity_tuesday['T7'].mean()
avg_temp_tuesday
# Out:
# 20.300834268645566

# %%
temp_humidity_wednesday = temp_humidity[data.Day_of_week == 'Wednesday']
temp_humidity_wednesday
# Out:
#               T7       RH_7 Day_of_week
# 142    17.840000  42.495000   Wednesday
# 143    17.804286  42.586429   Wednesday
# 144    17.815000  42.900000   Wednesday
# 145    17.890000  43.156000   Wednesday
# 146    17.890000  43.200000   Wednesday
# 147    17.890000  43.427143   Wednesday
# 148    17.890000  43.590000   Wednesday
# 149    17.890000  43.862222   Wednesday
# 150    17.890000  44.000000   Wednesday
# 151    17.890000  44.365000   Wednesday
# 152    17.979375  44.679375   Wednesday
# 153    18.000000  44.765000   Wednesday
# 154    18.000000  44.681667   Wednesday
# 155    18.000000  44.608333   Wednesday
# 156    18.000000  44.714444   Wednesday
# 157    18.011111  44.785000   Wednesday
# 158    18.033333  44.755000   Wednesday
# 159    18.061111  44.794444   Wednesday
# 160    18.027778  44.694444   Wednesday
# 161    18.000000  44.657222   Wednesday
# 162    18.000000  44.669444   Wednesday
# 163    18.050000  44.663333   Wednesday
# ...

# %%
avg_temp_wednesday = temp_humidity_wednesday['T7'].mean()
avg_temp_wednesday
# Out:
# 20.150072266692398

# %%
temp_humidity_thursday = temp_humidity[data.Day_of_week == 'Thursday']
temp_humidity_thursday
# Out:
#               T7       RH_7 Day_of_week
# 261    18.100000  39.966667    Thursday
# 262    18.100000  40.066667    Thursday
# 263    18.100000  40.260000    Thursday
# 264    18.100000  40.663333    Thursday
# 265    18.100000  40.845000    Thursday
# 266    18.100000  41.096667    Thursday
# 267    18.100000  41.363333    Thursday
# 268    18.100000  41.626667    Thursday
# 269    18.100000  41.963333    Thursday
# 270    18.100000  42.090000    Thursday
# 271    18.100000  42.090000    Thursday
# 272    18.100000  42.223333    Thursday
# 273    18.100000  42.433333    Thursday
# 274    18.100000  42.433333    Thursday
# 275    18.100000  42.466667    Thursday
# 276    18.100000  42.363333    Thursday
# 277    18.100000  42.363333    Thursday
# 278    18.100000  42.466667    Thursday
# 279    18.100000  42.400000    Thursday
# 280    18.100000  42.466667    Thursday
# 281    18.000000  42.200000    Thursday
# 282    18.000000  42.200000    Thursday
# ...

# %%
avg_temp_thursday = temp_humidity_thursday['T7'].mean()
avg_temp_thursday
# Out:
# 20.270862961227454

# %%
temp_humidity_friday = temp_humidity[data.Day_of_week == 'Friday']
temp_humidity_friday
# Out:
#               T7       RH_7 Day_of_week
# 369    18.600000  41.266667      Friday
# 370    18.600000  41.526667      Friday
# 371    18.600000  41.656667      Friday
# 372    18.600000  41.863333      Friday
# 373    18.600000  41.900000      Friday
# 374    18.600000  41.900000      Friday
# 375    18.600000  42.000000      Friday
# 376    18.600000  42.000000      Friday
# 377    18.500000  42.230000      Friday
# 378    18.500000  42.363333      Friday
# 379    18.500000  42.400000      Friday
# 380    18.500000  42.400000      Friday
# 381    18.500000  42.400000      Friday
# 382    18.500000  42.400000      Friday
# 383    18.500000  42.400000      Friday
# 384    18.500000  42.326667      Friday
# 385    18.500000  42.466667      Friday
# 386    18.500000  42.500000      Friday
# 387    18.500000  42.500000      Friday
# 388    18.500000  42.433333      Friday
# 389    18.500000  42.760000      Friday
# 390    18.500000  42.760000      Friday
# ...

# %%
avg_temp_friday = temp_humidity_friday['T7'].mean()
avg_temp_friday
# Out:
# 20.240715661315264

# %%
avg_humidity_monday = temp_humidity_monday['RH_7'].mean()
avg_humidity_monday
# Out:
# 35.489950698190924

# %%
avg_humidity_tuesday = temp_humidity_tuesday['RH_7'].mean()
avg_humidity_tuesday
# Out:
# 35.60048019053757

# %%
avg_humidity_wednesday = temp_humidity_wednesday['RH_7'].mean()
avg_humidity_wednesday
# Out:
# 35.083863390848876

# %%
avg_humidity_thursday = temp_humidity_thursday['RH_7'].mean()
avg_humidity_thursday
# Out:
# 34.92604272535431

# %%
avg_humidity_friday = temp_humidity_friday['RH_7'].mean()
avg_humidity_friday
# Out:
# 35.52658714382348

# %%
temp_weekday = [avg_temp_monday,avg_temp_tuesday,avg_temp_wednesday,avg_temp_thursday,avg_temp_friday]
week_days = ['monday','tuesday','wednesday','thursday','friday']
pt.bar(week_days,temp_weekday,color='g',width=0.50,label='temperature')
pt.xlabel('Weekdays')
pt.ylabel('Tempertures')
pt.title('Average  ironing room temperatures in weekday')
pt.legend(loc=(1.1,0.4))

# %%
humidity_weekday = [avg_humidity_monday,avg_humidity_tuesday,avg_humidity_wednesday,avg_humidity_thursday,avg_humidity_friday]
week_days = ['monday','tuesday','wednesday','thursday','friday']
pt.bar(week_days,humidity_weekday,color='b',width=0.50,label='Humidity')
pt.xlabel('Weekdays')
pt.ylabel('Humidity')
pt.title('Average ironing humidity in weekday')
pt.legend(loc=(1.1,0.4))
